# %%
#if문은 왜 필요할까
## 돈이 있으면 택시를 타고 가고,돈이 없으면 걸어가라

money = True
if money == True:
    print('택시를 타고 가라')
else:
    print('걸어가라')
# Out:
# 택시를 타고 가라

# %%
#if문의 구조
#if 조건문:
#    수행할 문장1
#    수행할 문장2
#else:
#    수행할 문장3
#    수행할 문장4
# Out:
#   Cell In[2], line 5
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
#들여쓰기 방법
money=True
if money:
    print("택시를")

print("타고")#여기까지는 원래 출력 가능
    print("가라")
# Out:
#   Cell In[3], line 7
#     print("가라")
#     ^
# IndentationError: unexpected indent

# %%
if money:
    print("택시를")
    print("타고")
           print("가라")
# Out:
#   Cell In[4], line 4
#     print("가라")
#     ^
# IndentationError: unexpected indent

# %%
"만약 3000원 이상의 돈을 가지고 있으면 택시를 타고 가고 그렇지 않으면 걸어가라"
money = 3000
if money >= 3000:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
"돈이 3000원 이상 있거나 카드가 있다면 택시를 타고 가고 그렇지 않으면 걸어가라"

money=2000
card=True
if money>=3000 or card:
    print("택시를 타라")
else:
    print("걸어가라")
# Out:
# 택시를 타라

# %%
"달걀이 있으면 우유를 6개 사와"
if 달걀 == True:
    print('우유를 사와')
else:
    print('달걀을 사와 ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 "달걀이 있으면 우유를 6개 사와"
# ----> 2 if 달걀 == True:
#       3     print('우유를 사와')
#       4 else:
#
# NameError: name '달걀' is not defined

# %%
#다양한 조건을 판단하는 elif
#주머니에 돈이 있으면 택시를 타고가고
#주머니에 돈은 없지만 카드가 있으면 택시를 타고가고
#돈도 없고 카드도 없으면 걸어가라
pocket=['papre','phone']
card=True 
if "money" in pocket:
    print('1.택시를 타고 가라')
elif card == True:
    print('2.택시를 타고 가라')

else:
    print('걸어가라')
# Out:
# 2.택시를 타고 가라
